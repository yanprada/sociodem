# %%
from src.tools.databases.data_connection.connection import DBConnection
from src.databases.bronze.aneel.config import CONTRACT_BRONZE_ENERGY
from src.tools.utils.common import get_db_path


PATH = get_db_path(CONTRACT_BRONZE_ENERGY["aneel_join_2017"])
CODIGO_IBGE = '3538709'  # Piracicaba, SP
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 from src.tools.databases.data_connection.connection import DBConnection
# ----> 2 from src.databases.bronze.aneel.config import CONTRACT_BRONZE_ENERGY
#       3 from src.tools.utils.common import get_db_path
#       6 PATH = get_db_path(CONTRACT_BRONZE_ENERGY["aneel_join_2017"])
#
# File ~/projetos/sociodem/.venv/lib/python3.10/site-packages/src-0.1.0-py3.10.egg/src/databases/bronze/aneel/config.py:15
#       1 """
#       2 This module contains the configuration settings for the bronze database related to the ANEEL data.
#       3
#    (...)
#       9
#      10 """
#      12 import os
# ---> 15 from src.tools.managers.execution import ExecutionManagerWrapper
#      17 # main run = "bronze-aneel-2025-03-13-15h51m53s"
#      19 EXECUTION_ID = "bronze-aneel-2025-05-14-14h36m13s"
#
# ...

# %%
import sys
sys.executable
# Out:
# '/home/yan/projetos/sociodem/.venv/bin/python'

# %%
import sys
sys.path.append("/home/yan/projetos/sociodem/.venv/bin")

# %%
conn = DBConnection("bronze")

df = conn.query_database(f"""SELECT * FROM {PATH} WHERE mun = '{CODIGO_IBGE}' """)
